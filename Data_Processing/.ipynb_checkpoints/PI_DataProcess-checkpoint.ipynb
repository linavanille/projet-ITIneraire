# %%
import pandas as pd
import os
from utils import convert_gpx_to_csv
from Struc_stat_gps import Donnees_gps

# %%
root = "../output/"

#SEPARATION_ALTITUDE = trace_RPi.Altitude.isnull().values.sum()

def gpx_to_csv(paff):
    if not os.path.exists(paff+".csv"):
        convert_gpx_to_csv(paff+".gpx", paff+".csv")

def import_Data(paff):
    sources = ("_RPI", "_Chloe", "_Thomas")
    for src in sources[1:] :
        gpx_to_csv(root+paff+"/GPS_"+paff+src)
    df = [pd.read_csv((root+paff+"/GPS_"+paff+src+".csv")) for src in sources]

    return df[0], df[1], df[2]

#gps_data1 = pd.read_csv(acquisitionGPS_1)
#gps_data2 = pd.read_csv(acquisitionGPS_2)

#trace_RPi = pd.concat([gps_data1, gps_data2])

# %%
def nb_NaN(df):
    return df.isnull().values.sum()

def compare_Timestamp(tstmp_RPi, tstmp):
    return tstmp_RPi+"Z" == tstmp

# %%
d = Donnees_gps("borne")
# Out:
# /!\ Warning : Des colonnes sont manquantes pour la source Chloe => ['Date_Formatee', 'Latitude', 'Longitude']
# /!\ Warning : Des colonnes sont manquantes pour la source Thomas => ['Date_Formatee', 'Latitude', 'Longitude']
# Index(['Latitude', 'Longitude', 'Altitude'], dtype='object')

# %%
d.match_date
# Out:
#                          Date  Thomas_Longitude  Thomas_Latitude  \
# 0   2025-03-18 17:12:11+00:00               NaN              NaN
# 1   2025-03-18 17:12:12+00:00               NaN              NaN
# 2   2025-03-18 17:12:13+00:00               NaN              NaN
# 3   2025-03-18 17:12:15+00:00               NaN              NaN
# 4   2025-03-18 17:12:16+00:00          1.068238        49.385783
# ..                        ...               ...              ...
# 97  2025-03-18 17:13:49+00:00          1.068238        49.385783
# 98  2025-03-18 17:13:50+00:00          1.068238        49.385783
# 99  2025-03-18 17:13:51+00:00          1.068238        49.385783
# 100 2025-03-18 17:13:52+00:00          1.068238        49.385783
# 101 2025-03-18 17:13:53+00:00          1.068238        49.385783
#
#      Chloe_Longitude  Chloe_Latitude  RPI_Longitude  RPI_Latitude
# 0                NaN             NaN       1.068251     49.385757
# 1                NaN             NaN       1.068253     49.385760
# 2                NaN             NaN       1.068254     49.385762
# 3           1.068243       49.385798            NaN           NaN
# 4           1.068247       49.385807       1.068256     49.385767
# ..               ...             ...            ...           ...
# 97          1.068248       49.385782            NaN           NaN
# 98          1.068249       49.385783            NaN           NaN
# 99          1.068249       49.385783            NaN           NaN
# 100         1.068248       49.385783            NaN           NaN
# 101              NaN             NaN            NaN           NaN
#
# [102 rows x 7 columns]

# %%
min({2:3,4:8,1:5})
# Out:
# 1
